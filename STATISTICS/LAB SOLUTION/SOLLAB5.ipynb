# %% [markdown]
#  1 ]  normal distribution

# %%
from scipy.stats import norm
norm.cdf(1.5)
# Out:
# 0.6914624612740131

# %%
from scipy.stats import norm
m=norm.cdf(1.5)-norm.cdf(-1.5)
print(round(m,4))
# Out:
# 0.8664

# %%
from scipy.stats import norm
norm.cdf(-0.5)
# Out:
# 0.3085375387259869

# %%
from scipy.stats import norm
1-(norm.cdf(0.5)-norm.cdf(-0.5))
# Out:
# 0.6170750774519738

# %%
from scipy.stats import norm
p=norm.cdf(1)-norm.cdf(-2.2)
print(round(p,4))
# Out:
# 0.8274

# %% [markdown]
#  2 ] Standard normal distribution

# %%
from scipy.stats import norm
norm.ppf(0.90)
# Out:
# 1.2815515655446004

# %%
from scipy.stats import norm

norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
from scipy.stats import norm
norm.ppf(0.99)
# Out:
# 2.3263478740408408

# %%
from scipy.stats import norm
norm.ppf(0.95)
# Out:
# 1.6448536269514722

# %%
from scipy.stats import norm
norm.ppf(0.975)
# Out:
# 1.959963984540054

# %%
from scipy.stats import norm
norm.ppf(0.995)
# Out:
# 2.5758293035489004

# %% [markdown]
#  3 ]

# %%
from scipy.stats import t
t.cdf(1.5,20)
# Out:
# 0.9253821144153737

# %%
from scipy.stats import t

t.cdf(-0.5,15)
# Out:
# 0.3121650567600378

# %%
from scipy.stats import t
t.cdf(1.5,25)-t.cdf(-1.5,25)
# Out:
# 0.8538615348619807

# %%
from scipy.stats import t
1-(t.cdf(0.5,35)-t.cdf(-0.5,35))
# Out:
# 0.6202043032354957

# %%
from scipy.stats import t
t.cdf(1,42)-t.cdf(-2.2,42)
# Out:
# 0.8218007171327162

# %% [markdown]
# 4 ]

# %%
from scipy.stats import t
t.ppf(0.90,20)
# Out:
# 1.3253407069850462

# %%
from scipy.stats import t
t.ppf(0.95,15)
# Out:
# 1.7530503556925547

# %%
from scipy.stats import t
t.ppf(0.99,25)
# Out:
# 2.4851071754106413

# %%
from scipy.stats import t
t.ppf(0.90,30)-t.ppf(-0.90,30)
# Out:
# nan

# %%
from scipy.stats import t
t.ppf(0.95,42)
# Out:
# 1.6819523559426

# %%
from scipy.stats import t
t.ppf(0.99,10)
# Out:
# 2.763769457447889

# %% [markdown]
# 5 ]

# %%
from scipy.stats import f
f.cdf(1.5,5,14)
# Out:
# 0.7480582329156877

# %%
from scipy.stats import f
1-(f.cdf(2.5,15,14))
# Out:
# 0.04734368894060448

# %%
from scipy.stats import f
1-(f.cdf(0.5,13,17)-f.cdf(-4.1,13,17))
# Out:
# 0.8949813993120213

# %% [markdown]
#  6 ]

# %%
from scipy.stats import f
f.ppf(0.90,5,14)
# Out:
# 2.3069430514007236

# %%
from scipy.stats import f

f.ppf(0.95,15,13)
# Out:
# 2.533109983130745

# %%
from scipy.stats import f
f.ppf(0.99,25,28)
# Out:
# 2.5060172667359417

# %% [markdown]
# 7 ]

# %%
from scipy.stats import chi2
chi2.cdf(1.5,10)
# Out:
# 0.0010646777727857928

# %%
from scipy.stats import chi2
1-(chi2.cdf(2.5,5))
# Out:
# 0.7764950711233227

# %%
from scipy.stats import chi2
chi2.cdf(0.5,2)-chi2.cdf(-4.1,2)
# Out:
# 0.22119921692859512

# %% [markdown]
#  8 ]

# %%
from scipy.stats import chi2
chi2.ppf(0.90,1)
# Out:
# 2.705543454095404

# %%
from scipy.stats import chi2
chi2.ppf(0.95,3)
# Out:
# 7.814727903251179

# %%
from scipy.stats import chi2
chi2.ppf(0.99,2)
# Out:
# 9.21034037197618

# %%
from scipy.stats import chi2
chi2.ppf(0.05,1)
# Out:
# 0.003932140000019522

# %%
from scipy.stats import chi2
chi2.ppf(0.025,3)
# Out:
# 0.21579528262389785

# %%
from scipy.stats import chi2
chi2.ppf(0.005,2)
# Out:
# 0.010025083647088564
