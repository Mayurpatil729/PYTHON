# %% [markdown]
#  1] PROGRAM FOR HISTOGRAM

# %%
from matplotlib import pyplot as plt
import numpy as np
 
# Creating dataset
x= np.random.normal(170,10,250) 
# Creating histogram
plt.hist(x)
# Show plot
plt.show()

# %% [markdown]
#   2 ] PROGRAM FOR HISTOGRAM

# %%
from matplotlib import pyplot as plt
import numpy as np
y= (43.1,35.6,37.6,36.6,45.3,43.5,40.3,50.2,47.3,31.2,42.2,45.5,30.3,31.4,35.6,45.2,54.1,45.6,36.5,43.1)
plt.hist(y)
plt.show()

# %% [markdown]
#  3 ] PROGRAM FOR  IMPORT FILES BMI

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-5f3374bd-5006-465e-b455-64d5428aa5e5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f3374bd-5006-465e-b455-64d5428aa5e5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df=pd.read_csv('bmi (2).csv')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as seconds_in_a_day
# %matplotlib inline
d=df.describe()
print(d)

# %%
df.boxplot(column="Age")
##Bocplot grouped by gender category
df.boxplot(column ="Age",by = "Gender")
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/cbook/__init__.py:1376: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   X = np.atleast_1d(X.T if isinstance(X, np.ndarray) else np.asarray(X))

# %% [markdown]
#  4 ] HISTOGRAM 4

# %%
df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7fa6401cf610>,
# ...
#       dtype=object)
