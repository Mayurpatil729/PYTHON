# %% [markdown]
#  1 ]

# %%
import numpy.random as np
import seaborn as sns
import matplotlib.pyplot as plt
population_size= 100000
population=np.rand(population_size)
number_of_samples = 10000
sample_size=30
c=np.rand(number_of_samples)  # Random values in a given shape
for i in  range(0,number_of_samples):
c=np.randint(1,population_size,sample_size) #Return random integers
sample_means[i] = population[c].mean()
plt.subplot (1,2,1)
sns.distplot(sample_means,bins=int(180/5),hist=True,kde =False)
plt.title("Histogram of sample mean",fontsize =20)
plt.xlabel("Sample mean",fontsize =20)
plt.ylabel("count",fontsize =20)
plt.subplot(1,2,2)
sns.distplot(sample_means, hist=False,kde=True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1,right =2,top=0.9)
# Out:
#   File "<ipython-input-20-f4ae441455da>", line 12
#     plt.subplot(1,2,1)
#       ^
# IndentationError: expected an indented block

# %%
import numpy.random as np
import seaborn as sns
import matplotlib.pyplot as plt
population_size= 1000000
population=np.rand(population_size)
number_of_samples = 100000
sample_size=30
c=np.rand(number_of_samples)  # Random values in a given shape
for i in  range(0,number_of_samples):
  c = np.randint(1,population_size,sample_size) #Return random integer
  sample_means[i] = population[c].mean()
plt.subplot (1,2,1)
sns.distplot(sample_means,bins=int(180/5),hist=True,kde =False)
plt.title("Histogram of sample mean",fontsize =20)
plt.xlabel("Sample mean",fontsize =20)
plt.ylabel("count",fontsize =20)
plt.subplot(1,2,2)
sns.distplot(sample_means, hist=False,kde=True)
plt.title("Density of Sample mean",fontsize=20)
plt.xlabel("sample mean",fontsize=20)
plt.ylabel("Density",fontsize=20)
plt.subplots_adjust(bottom=0.1,right =2,top=0.9)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-a5c33dadda90> in <module>
#       9 for i in  range(0,number_of_samples):
#      10   c = np.randint(1,population_size,sample_size) #Return random integer
# ---> 11   sample_means[i] = population[c].mean()
#      12 plt.subplot (1,2,1)
#      13 sns.distplot(sample_means,bins=int(180/5),hist=True,kde =False)
#
# NameError: name 'sample_means' is not defined
