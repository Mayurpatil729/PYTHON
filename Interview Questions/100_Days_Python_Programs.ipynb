# %% [markdown]
# ### 1. Take 3 ages from user and find Oldest one

# %%
Age1=int(input("Enter Age1:"))
Age2=int(input("Enter Age2:"))
Age3=int(input("Enter Age3:"))
if Age1>Age2 and Age1>Age3:
    print(f"{Age1}")
elif Age2>Age1 and Age2>Age3:
    print(f"{Age2}")
else:
    print(f"{Age3}")
# Out:
# 100

# %% [markdown]
# ### 2.Write a program that will convert celsius value to fahrenheit

# %%
c=int(input("Enter the value of Celsisus : "))
f=(c*(9/5))+32
print(f)
# Out:
# 98.60000000000001

# %% [markdown]
# ### 3.Write a program that will give you the sum of 3 digits

# %%
# num1=int(input("Enter the first number : "))
# num2=int(input("Enter the second number : "))
# num3=int(input("Enter the third number : "))
# sum=num1+num2+num3
# print("The sum of 3 numbers : ",sum)

#################################################

num=int(input("Enter the 3 digit number : "))
sum=0
while num>0:
    rem=num%10
    sum=sum+rem
    num=num//10
    
print(sum)
# Out:
# 14

# %% [markdown]
# ### 4. Swaping of Numbers.

# %%
num1=int(input("Enter the first number : "))
num2=int(input("Enter the second number : "))

print(f"Before swaping number will be num1 : {num1} and num2 : {num2}")

num1=num1+num2
num2=num1-num2
num1=num1-num2

print(f"After swaping number will be num1 : {num1} and num2 : {num2}")

# a,b=b,a
# Out:
# Before swaping number will be num1 : 50 and num2 : 100
# After swaping number will be num1 : 100 and num2 : 50

# %% [markdown]
# ### 5. Write a program that will reverse a four digit number.Also it checks whether the reverse is true.

# %%
num=int(input("Enter the four digit number : "))

temp=num
rev=0
while num>0:
    rem=num%10
    num=num//10
    rev=rev*10+rem

print(f"The reverse of {temp} : ",rev) 
if rev==temp:
    print("Reverse is True")
else:
    print("Reverse is False")
# Out:
# The reverse of 1441 :  1441
# Reverse is True

# %% [markdown]
# ### 6.Write a program that will tell whether the number entered by the user is odd or even

# %%
num=int(input("Enter the number : "))
print("Enter number is : ",num)
if num==0:
    print("Number is zero")
elif num>0:
    print("Number is Positive")
else:
    print("Number is negative")
# Out:
# Enter number is :  69
# Number is Positive

# %% [markdown]
# ### 7.Write a program that will tell whether the given year is a leap year or not.

# %%
year=int(input("Enter the year : "))
if (year%4==0 and (year%100!=0 or year%400==0)):
    print("Given year is leap year")
else:
    print("Not leap year")
# Out:
# Not leap year
